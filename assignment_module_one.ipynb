# %% [markdown]
# <a href="https://colab.research.google.com/github/Airdef/CV/blob/main/assignment_module_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Product Recognition of Food Products**
#
# ## Image Processing and Computer Vision - Assignment Module \#1
#
#
# Contacts:
#
# - Prof. Giuseppe Lisanti -> giuseppe.lisanti@unibo.it
# - Prof. Samuele Salti -> samuele.salti@unibo.it
# - Alex Costanzino -> alex.costanzino@unibo.it
# - Francesco Ballerini -> francesco.ballerini4@unibo.it
#
#
# Computer vision-based object detection techniques can be applied in super market settings to build a system that can identify products on store shelves.
# An example of how this system could be used would be to assist visually impaired customers or automate common store management tasks like detecting low-stock or misplaced products, given an image of a shelf in a store.

# %% [markdown]
# ## Task
# Develop a computer vision system that, given a reference image for each product, is able to identify such product from one picture of a store shelf.
#
# <figure>
# <a href="https://imgbb.com/">
#   <center>
#   <img src="https://i.ibb.co/TwkMWnH/Screenshot-2024-04-04-at-14-54-51.png" alt="Screenshot-2024-04-04-at-14-54-51" border="0" width="300" />
# </a>
# </figure>
#
# For each type of product displayed in the
# shelf the system should report:
# 1. Number of instances;
# 1. Dimension of each instance (width and height in pixel of the bounding box that enclose them);
# 1. Position in the image reference system of each instance (center of the bounding box that enclose them).
#
# #### Example of expected output
# ```
# Product 0 - 2 instance found:
#   Instance 1 {position: (256, 328), width: 57px, height: 80px}
#   Instance 2 {position: (311, 328), width: 57px, height: 80px}
# Product 1 – 1 instance found:
# .
# .
# .
# ```
#
# ### Track A - Single Instance Detection
# Develop an object detection system to identify single instance of products given one reference image for each item and a scene image.
#
# The system should be able to correctly identify all the product in the shelves
# image.
#
# ### Track B - Multiple Instances Detection
# In addition to what achieved at step A, the system should also be able to detect multiple instances of the same product.

# %% [markdown]
# ## Data
# Two folders of images are provided:
# * **Models**: contains one reference image for each product that the system should be able to identify.
# * **Scenes**: contains different shelve pictures to test the developed algorithm in different scenarios. The images contained in this folder are corrupted by noise.
#
# #### Track A - Single Instance Detection
# * **Models**: {ref1.png to ref14.png}.
# * **Scenes**: {scene1.png to scene5.png}.
#
# #### Track B - Multiple Instances Detection
# * **Models**: {ref15.png to ref27.png}.
# * **Scenes**: {scene6.png to scene12.png}.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# !cp -r /content/drive/MyDrive/AssignmentsIPCV/dataset.zip ./
# !unzip dataset.zip
# Out:
# Mounted at /content/drive
# Archive:  dataset.zip
#    creating: dataset/
#   inflating: __MACOSX/._dataset
#    creating: dataset/scenes/
#   inflating: __MACOSX/dataset/._scenes
#   inflating: dataset/.DS_Store
#   inflating: __MACOSX/dataset/._.DS_Store
#    creating: dataset/models/
#   inflating: __MACOSX/dataset/._models
#   inflating: dataset/scenes/scene12.png
#   inflating: __MACOSX/dataset/scenes/._scene12.png
#   inflating: dataset/scenes/scene10.png
#   inflating: __MACOSX/dataset/scenes/._scene10.png
#   inflating: dataset/scenes/scene11.png
#   inflating: __MACOSX/dataset/scenes/._scene11.png
#   inflating: dataset/scenes/scene5.png
#   inflating: __MACOSX/dataset/scenes/._scene5.png
#   inflating: dataset/scenes/scene4.png
#   inflating: __MACOSX/dataset/scenes/._scene4.png
#   inflating: dataset/scenes/scene6.png
#   inflating: __MACOSX/dataset/scenes/._scene6.png
#   inflating: dataset/scenes/scene7.png
#   inflating: __MACOSX/dataset/scenes/._scene7.png
#   inflating: dataset/scenes/scene3.png
#   inflating: __MACOSX/dataset/scenes/._scene3.png
#   inflating: dataset/scenes/scene2.png
#   inflating: __MACOSX/dataset/scenes/._scene2.png
#   inflating: dataset/scenes/scene1.png
#   inflating: __MACOSX/dataset/scenes/._scene1.png
#   inflating: dataset/scenes/scene9.png
#   inflating: __MACOSX/dataset/scenes/._scene9.png
#   inflating: dataset/scenes/scene8.png
#   inflating: __MACOSX/dataset/scenes/._scene8.png
#   inflating: dataset/models/ref8.png
#   inflating: __MACOSX/dataset/models/._ref8.png
#   inflating: dataset/models/ref9.png
#   inflating: __MACOSX/dataset/models/._ref9.png
#   inflating: dataset/models/ref12.png
#   inflating: __MACOSX/dataset/models/._ref12.png
#   inflating: dataset/models/ref13.png
#   inflating: __MACOSX/dataset/models/._ref13.png
#   inflating: dataset/models/ref11.png
#   inflating: __MACOSX/dataset/models/._ref11.png
#   inflating: dataset/models/ref10.png
#   inflating: __MACOSX/dataset/models/._ref10.png
#   inflating: dataset/models/ref14.png
#   inflating: __MACOSX/dataset/models/._ref14.png
#   inflating: dataset/models/ref15.png
#   inflating: __MACOSX/dataset/models/._ref15.png
#   inflating: dataset/models/ref17.png
#   inflating: __MACOSX/dataset/models/._ref17.png
#   inflating: dataset/models/ref16.png
#   inflating: __MACOSX/dataset/models/._ref16.png
#   inflating: dataset/models/ref27.png
#   inflating: __MACOSX/dataset/models/._ref27.png
#   inflating: dataset/models/ref26.png
#   inflating: __MACOSX/dataset/models/._ref26.png
#   inflating: dataset/models/ref18.png
#   inflating: __MACOSX/dataset/models/._ref18.png
#   inflating: dataset/models/ref24.png
#   inflating: __MACOSX/dataset/models/._ref24.png
#   inflating: dataset/models/ref25.png
#   inflating: __MACOSX/dataset/models/._ref25.png
#   inflating: dataset/models/ref19.png
#   inflating: __MACOSX/dataset/models/._ref19.png
#   inflating: dataset/models/ref21.png
#   inflating: __MACOSX/dataset/models/._ref21.png
#   inflating: dataset/models/ref20.png
#   inflating: __MACOSX/dataset/models/._ref20.png
#   inflating: dataset/models/ref22.png
#   inflating: __MACOSX/dataset/models/._ref22.png
#   inflating: dataset/models/ref23.png
#   inflating: __MACOSX/dataset/models/._ref23.png
#   inflating: dataset/models/ref7.png
#   inflating: __MACOSX/dataset/models/._ref7.png
#   inflating: dataset/models/ref6.png
#   inflating: __MACOSX/dataset/models/._ref6.png
#   inflating: dataset/models/ref4.png
#   inflating: __MACOSX/dataset/models/._ref4.png
#   inflating: dataset/models/ref5.png
#   inflating: __MACOSX/dataset/models/._ref5.png
#   inflating: dataset/models/ref1.png
#   inflating: __MACOSX/dataset/models/._ref1.png
#   inflating: dataset/models/ref2.png
#   inflating: __MACOSX/dataset/models/._ref2.png
#   inflating: dataset/models/ref3.png
#   inflating: __MACOSX/dataset/models/._ref3.png

# %% [markdown]
# ## Evaluation criteria
# 1. **Procedural correctness**. There are several ways to solve the assignment. Design your own sound approach and justify every decision you make;
#
# 2. **Clarity and conciseness**. Present your work in a readable way: format your code and comment every important step;
#
# 3. **Correctness of results**. Try to solve as many instances as possible. You should be able to solve all the instances of the assignment, however, a thoroughly justified and sound procedure with a lower number of solved instances will be valued **more** than a poorly designed approach.

# %% [markdown]
# **TASK A**

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import os

# %% [markdown]
# TASK A

# %%
class sift_value:
  def __init__(self,path, name=None):
    self.name = name
    self.img= cv2.imread(path)
    self.kp, self.des = sift.detectAndCompute(self.img,None)

  def match_k(self, img_c,min_match_count=10,dis=0.7,see=False):

    FLANN_INDEX_KDTREE = 1
    index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
    search_params = dict(checks = 50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)
    matches = flann.knnMatch(self.des,img_c.des,k=2)
    # store all the good matches as per Lowe's ratio test.
    good = []

    for m,n in matches:
        if m.distance < dis*n.distance:
            good.append(m)
    if len(good)>min_match_count:
        src_pts = np.float32([self.kp[m.queryIdx].pt for m in good]).reshape(-1,1,2)
        dst_pts = np.float32([img_c.kp[m.trainIdx].pt for m in good]).reshape(-1,1,2)
        M, mask = cv2.findHomography(dst_pts, src_pts, cv2.RANSAC, 5.0)
        if M is not None:

          matchesMask = mask.ravel().tolist()

          h,w = img_c.img.shape[:2]
          pts = np.float32([ [0,0],[0,h-1],[w-1,h-1],[w-1,0] ]).reshape(-1,1,2)

          dst = cv2.perspectiveTransform(pts,M)
          #dst += (w, 0)  # adding offset

###########################################

          dst2 = dst.reshape(-1, 2)
          rect = cv2.minAreaRect(dst2)
          box = cv2.boxPoints(rect)
          box = np.intp(box)

          center = np.mean(box, axis=0)

          out = cv2.drawContours(self.img.copy(), [box], 0, (255, 0, 0), 5)

          print(f"found, model: {img_c.name}   scene: {self.name}")

          if see:
            self.show()
            img_c.show()

            plt.imshow(cv2.cvtColor(out, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.title("boxes")
            plt.show()


          return  tuple(int(float(x)) for x in rect[0]), int(rect[1][0]),int(rect[1][1])
    else:
      print(f"no found, model: {img_c.name}   scene: {self.name}")

      return None

  def show(self):
    plt.imshow(cv2.cvtColor(self.img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(self.name)
    plt.show()

# %%
sift = cv2.xfeatures2d.SIFT_create()
counter=0
good=0
for scene_name in os.listdir("/content/dataset/scenes"):

  scene=sift_value(path=f"/content/dataset/scenes/{scene_name}",name=scene_name)


  for model_name in os.listdir("/content/dataset/models"):

    model=sift_value(path=f"/content/dataset/models/{model_name}",name=model_name)


    result= scene.match_k(model,dis=0.5,min_match_count=20)
    counter+=1
    if result:
      good+=1
      center_box,width_box,height_box=result
      print(center_box,width_box,height_box)

# %%
print(f"good: {good}, tot: {counter}")

# %% [markdown]
# TASK B

# %%
class sift_value:

  def __init__(self,path, name=None):
    self.name = name
    self.img= cv2.imread(path)


    self.kp, self.des = sift.detectAndCompute(self.img,None)


  def match_k(self, img_c,min_match_count=10,dis=0.7,see=False):



    img=cv2.medianBlur(self.img, 5)
    #img = cv2.bilateralFilter(img,5, 6,6)
    blurred = cv2.GaussianBlur(img, (7, 7), 2)

    # Enhance edges by subtracting the blurred image from the original
    self.img= cv2.addWeighted(img, 1.5, blurred, -0.5, 0)
    #img = cv2.bilateralFilter(img,5, 6,6)

    istances=0
    middle=self.img.copy()
    out=self.img.copy()

    # Setup FLANN matcher
    FLANN_INDEX_KDTREE = 1
    index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
    search_params = dict(checks=50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)


    while True:


        # Match descriptors
        matches = flann.knnMatch(self.des, img_c.des, k=2)
        # store all the good matches as per Lowe's ratio test.
        good = []

        for m,n in matches:
          if m.distance < dis*n.distance:
              good.append(m)

        if len(good) > min_match_count:
            # Compute homography
            src_pts = np.float32([self.kp[m.queryIdx].pt for m in good]).reshape(-1, 1, 2)
            dst_pts = np.float32([img_c.kp[m.trainIdx].pt for m in good]).reshape(-1, 1, 2)
            M, mask = cv2.findHomography(dst_pts, src_pts, cv2.RANSAC, 5.0)

            if M is not None:
                # Apply perspective transformation
                h, w = img_c.img.shape[:2]
                pts = np.float32([[0, 0], [0, h - 1], [w - 1, h - 1], [w - 1, 0]]).reshape(-1, 1, 2)
                dst = cv2.perspectiveTransform(pts, M)

                # Calculate the bounding box
                dst2 = dst.reshape(-1, 2)
                rect = cv2.minAreaRect(dst2)

                (center, size, angle) = rect

                # Scale the size
                scaled_size = (0.9 * size[0], 0.9 * size[1])

                # Create a new rectangle with the scaled size
                rect = (center, scaled_size, angle)
                box = cv2.boxPoints(rect)
                box = np.intp(box)

                distances = [np.linalg.norm(box[i] - box[(i + 1) % 4]) for i in range(4)]
                # Draw the bounding box
                middle = cv2.drawContours(middle, [box], 0, (255, 0, 0), -1)
                if min(distances)<50:
                  #out = cv2.drawContours(out, [box], 0, (255, 0, 0), 5)
                  break
                out = cv2.drawContours(out, [box], 0, (255, 0, 0), 5)
                istances += 1

                # Re-compute SIFT on modified middle image

                self.kp, self.des = sift.detectAndCompute(middle, None)


            else:
                break
        else:

            break

    if istances != 0:
        if see:
            self.show()
            img_c.show()
            plt.imshow(cv2.cvtColor(out, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.title("Detection")
            plt.show()

        return tuple(map(int, rect[0])), int(rect[1][0]), int(rect[1][1])
    else:
        print(f"No instances found, model: {img_c.name}   scene: {self.name}, Total instances: {istances}")
        return None

  def show(self):
    plt.imshow(cv2.cvtColor(self.img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(self.name)
    plt.show()

# %%
sift = cv2.xfeatures2d.SIFT_create()
counter=0
good=0
for scene_name in os.listdir("/content/dataset/scenes"):

  scene=sift_value(path=f"/content/dataset/scenes/{scene_name}",name=scene_name)


  for model_name in os.listdir("/content/dataset/models"):

    model=sift_value(path=f"/content/dataset/models/{model_name}",name=model_name)


    result= scene.match_k(model,dis=0.65,min_match_count=25,see=True)
    counter+=1
    if result:
      good+=1
      center_box,width_box,height_box=result
      print(center_box,width_box,height_box)
# Out:
# No instances found, model: ref12.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref3.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref19.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref15.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref6.png   scene: scene11.png, Total instances: 0
# (1142, 370) 434 166
# No instances found, model: ref26.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref18.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref21.png   scene: scene11.png, Total instances: 0
# (359, 370) 170 442
# No instances found, model: ref27.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref22.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref13.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref7.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref2.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref5.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref14.png   scene: scene11.png, Total instances: 0
# (742, 352) 170 410
# No instances found, model: ref20.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref1.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref11.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref8.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref9.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref23.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref10.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref16.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref4.png   scene: scene11.png, Total instances: 0
# No instances found, model: ref12.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref3.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref19.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref15.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref6.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref25.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref26.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref18.png   scene: scene8.png, Total instances: 0
# No instances found, model: ref21.png   scene: scene8.png, Total instances: 0
